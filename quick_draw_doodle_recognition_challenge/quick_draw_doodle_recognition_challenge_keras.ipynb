# %% [markdown]
# > **Problem overview**
#
# "Quick, Draw!" was released as an experimental game to educate the public in a playful way about how AI works. The game prompts users to draw an image depicting a certain category, such as ”banana,” “table,” etc. The game generated more than 1B drawings, of which a subset was publicly released as the basis for this competition’s training set. That subset contains 50M drawings encompassing 340 label categories.
#
# Sounds fun, right? Here's the challenge: since the training data comes from the game itself, drawings can be incomplete or may not match the label. You’ll need to build a recognizer that can effectively learn from this noisy data and perform well on a manually-labeled test set from a different distribution.
#
# Your task is to build a better classifier for the existing Quick, Draw! dataset. By advancing models on this dataset, Kagglers can improve pattern recognition solutions more broadly. This will have an immediate impact on handwriting recognition and its robust applications in areas including OCR (Optical Character Recognition), ASR (Automatic Speech Recognition) & NLP (Natural Language Processing).

# %%
# import python standard library
import ast, os

# import data manipulation library
import numpy as np
import pandas as pd

# import data visualization library
import matplotlib.pyplot as plt
from tqdm import tqdm

# import image processing library
import cv2

# import tensorflow model class
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, Dense, Dropout, Flatten, MaxPooling2D
from tensorflow.keras.models import load_model, Sequential

# import sklearn model selection
from sklearn.model_selection import train_test_split

# import tensorflow model evaluation classification metrics
from tensorflow.keras.metrics import top_k_categorical_accuracy

# %% [markdown]
# > **Acquiring training and testing data**
#
# We start by acquiring the training and testing datasets into Pandas DataFrames.

# %%
# acquiring training and testing data
df_train = pd.concat([pd.read_csv('../input/train_simplified/' + file, nrows=4) for file in os.listdir('../input/train_simplified')], ignore_index=True)
df_test = pd.read_csv('../input/test_simplified.csv', nrows=2)

# %%
# visualize head of the training data
df_train.head(n=5)
# Out:
#   countrycode     ...              word
# 0          US     ...       stethoscope
# 1          US     ...       stethoscope
# 2          PL     ...       stethoscope
# 3          KR     ...       stethoscope
# 4          US     ...               fan
#
# [5 rows x 6 columns]

# %%
# visualize tail of the testing data
df_test.tail(n=5)
# Out:
#              key_id                        ...                                                                    drawing
# 0  9000003627287624                        ...                          [[[17, 18, 20, 25, 137, 174, 242, 249, 251, 25...
# 1  9000010688666847                        ...                          [[[174, 145, 106, 38, 11, 4, 4, 15, 29, 78, 16...
#
# [2 rows x 3 columns]

# %%
# dataframe columns name
names = ['countrycode', 'drawing', 'key_id', 'recognized', 'timestamp', 'word']

# class files and dictionary
files = sorted([file.lower() for file in os.listdir('../input/train_simplified/')], reverse=False)
class_dict = {file[:-4].replace(" ", "_"): i for i, file in enumerate(files)}
classreverse_dict = {v: k for k, v in class_dict.items()}

# combine training and testing dataframe
df_train['datatype'], df_test['datatype'] = 'training', 'testing'
df_train = df_train[['key_id', 'countrycode', 'drawing', 'datatype', 'word', 'recognized']]
df_test['word'], df_test['recognized'] = '', True
df_data = pd.concat([df_train, df_test], ignore_index=True)

# %%
# data dimensions
img_size = 32
num_channels = 1
num_classes = 340

# flat dimensions
img_size_flat = img_size * img_size * num_channels

# %% [markdown]
# > **Feature exploration, engineering and cleansing**
#
# Here we generate descriptive statistics that summarize the central tendency, dispersion and shape of a dataset’s distribution together with exploring some data.

# %%
# drawplot function plot
def drawplot(drawing = None, label = None, ncols = 5, nrows = 3):
    fig, axes = plt.subplots(figsize=(4*ncols , 3*nrows), ncols=ncols, nrows=nrows)
    axes = axes.flatten()
    for i in label.index:
        for j in range(len(drawing[i])): _ = axes[i - label.index[0]].plot(drawing[i][j][0], drawing[i][j][1])
        axes[i - label.index[0]].invert_yaxis()
        axes[i - label.index[0]].set_title(label[i])

# %%
# imageplot function plot
def imageplot(pixel = None, label = None, ncols = 5, nrows = 3):
    fig, axes = plt.subplots(figsize=(4*ncols , 3*nrows), ncols=ncols, nrows=nrows)
    axes = axes.flatten()
    for i in range(len(label)): axes[i].imshow(pixel[i].reshape(img_size, img_size), interpolation='spline16')

# %%
# feature exploration, engineering and cleansing
def feature_extraction(df_data):
    # feature extraction: drawing
    df_data['drawing'] = df_data['drawing'].apply(lambda x: ast.literal_eval(x))
    
    # feature extraction: word
    df_data['word'] = df_data['word'].apply(lambda x: x.lower().replace(' ', '_'))
    
    # feature extraction: drawing to pixel
    def drawing2pixel(drawing = None):
        image, xmin, xmax, ymin, ymax = np.zeros((256, 256)), 255, 0, 255, 0
        for stroke in drawing:
            for i in range(len(stroke[0])-1):
                xmin, xmax = min(xmin, stroke[0][i], stroke[0][i + 1]), max(xmax, stroke[0][i], stroke[0][i + 1])
                ymin, ymax = min(ymin, stroke[1][i], stroke[1][i + 1]), max(ymax, stroke[1][i], stroke[1][i + 1])
                _ = cv2.line(image, (stroke[0][i], stroke[1][i]), (stroke[0][i + 1], stroke[1][i + 1]), color=1, thickness=5)
        if xmin == xmax: xmin, xmax = 0, 255
        if ymin == ymax: ymin, ymax = 0, 255
        return cv2.resize(image[ymin:ymax, xmin:xmax], (img_size, img_size))
    df_data['pixel'] = df_data['drawing'].apply(lambda x: drawing2pixel(x))
    
    return df_data

# %%
# feature extraction: step 1
df_data = feature_extraction(df_data)

# %%
# feature exploration: image
drawplot(df_data.loc[:19, 'drawing'], df_data.loc[:19, 'word'], nrows=4)

# %%
# feature exploration: image
imageplot(df_data.loc[:19, 'pixel'], df_data.loc[:19, 'word'], nrows=4)

# %% [markdown]
# After extracting all features, it is required to convert category features to numerics features, a format suitable to feed into our Machine Learning models.

# %%
# feature exploration, engineering and cleansing
def feature_extraction2(df_data):
    # feature extraction: remove countrycode and drawing
    df_data = df_data.drop(['countrycode', 'drawing'], axis=1)
    
    # convert category codes for data dataframe
    df_data = pd.get_dummies(df_data, columns=['datatype', 'word'], drop_first=False)
    
    return df_data

# %%
# feature extraction: step 2
df_data = feature_extraction2(df_data)

# %%
# describe data dataframe
df_data.describe(include='all')
# Out:
#               key_id recognized     ...        word_zebra  word_zigzag
# count   1.362000e+03       1362     ...       1362.000000  1362.000000
# unique           NaN          2     ...               NaN          NaN
# top              NaN       True     ...               NaN          NaN
# freq             NaN       1260     ...               NaN          NaN
# mean    5.604385e+15        NaN     ...          0.002937     0.002937
# std     6.575316e+14        NaN     ...          0.054133     0.054133
# min     4.505421e+15        NaN     ...          0.000000     0.000000
# 25%     5.031819e+15        NaN     ...          0.000000     0.000000
# 50%     5.579636e+15        NaN     ...          0.000000     0.000000
# 75%     6.155980e+15        NaN     ...          0.000000     0.000000
# max     9.000011e+15        NaN     ...          1.000000     1.000000
#
# [11 rows x 346 columns]

# %%
# verify dtypes object
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1362 entries, 0 to 1361
# Columns: 346 entries, key_id to word_zigzag
# dtypes: bool(1), int64(1), object(1), uint8(343)
# memory usage: 478.9+ KB

# %%
# memory clean-up
del df_data, df_train, df_test

# %%
# acquiring training data
list_of_data = []
for row in tqdm(range(1, 512, 64)):
    # acquiring training data
    df_data = pd.concat([pd.read_csv('../input/train_simplified/' + file, names=names, nrows=64, skiprows=row) for file in os.listdir('../input/train_simplified')], ignore_index=True)
    
    # combine training dataframe
    df_data['datatype'] = 'training'
    df_data = df_data[['key_id', 'countrycode', 'drawing', 'datatype', 'word', 'recognized']]
    
    # feature extraction: step 1
    df_data = feature_extraction(df_data)
    
    # feature extraction: step 2
    df_data = feature_extraction2(df_data)
    
    # feature extraction: append data dataframe
    list_of_data.append(df_data)
df_data = pd.concat(list_of_data, ignore_index=True)
# Out:
# 100%|██████████| 8/8 [01:46<00:00, 13.30s/it]

# %% [markdown]
# > **Model, predict and solve the problem**
#
# Now, it is time to feed the features to Machine Learning models.

# %%
# select all features
x = np.zeros((df_data.shape[0], img_size, img_size, 1))
for i, df_row in df_data.iterrows(): x[i, :, :, 0] = df_row['pixel']
y = df_data[[col for col in df_data if col.startswith('word')]]

# %%
# perform train-test (validate) split
x_train, x_validate, y_train, y_validate = train_test_split(x, y, random_state=58, test_size=0.10)

# %%
# memory clean-up
del df_data, x, y

# %% [markdown]
# A TensorFlow graph consists of the following parts which will be detailed below:
#
# * Placeholder variables used for inputting data to the graph.
# * Variables that are going to be optimized so as to make the convolutional network perform better.
# * The mathematical formulas for the convolutional network.
# * A loss measure that can be used to guide the optimization of the variables.
# * An optimization method which updates the variables.

# %%
# top_3_categorical_accuracy function
def top_3_categorical_accuracy(y_true, y_pred):
    return top_k_categorical_accuracy(y_true, y_pred, k=3)

# %%
# keras model setup
model_keras = Sequential()
model_keras.add(Conv2D(filters=32, kernel_size=(3, 3), strides=(1, 1), padding='same', activation='relu', input_shape=(img_size, img_size, 1)))
model_keras.add(MaxPooling2D(pool_size=(2, 2), padding='valid'))
model_keras.add(Conv2D(filters=64, kernel_size=(3, 3), strides=(1, 1), padding='same', activation='relu'))
model_keras.add(MaxPooling2D(pool_size=(2, 2), padding='valid'))
model_keras.add(Dropout(rate=0.2, seed=58))
model_keras.add(Flatten())
model_keras.add(Dense(680, activation='relu'))
model_keras.add(Dropout(rate=0.5, seed=58))
model_keras.add(Dense(num_classes, activation='softmax'))
model_keras.summary()
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/keras/layers/core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout (Dropout)            (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 680)               2785960
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 680)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 340)               231540
# =================================================================
# Total params: 3,036,316
# Trainable params: 3,036,316
# Non-trainable params: 0
# _________________________________________________________________

# %%
# keras model setup
model_keras.compile(optimizer='adam', loss='categorical_crossentropy', metrics=[top_3_categorical_accuracy])

# keras model fit
model_keras.fit(x_train, y_train, batch_size=32, epochs=80, verbose=2, validation_data=(x_validate, y_validate))

# keras model metrics
model_keras_score = model_keras.evaluate(x_validate, y_validate, verbose=1)
print('keras\n  top 3 categorical accuracy score: %0.4f' %model_keras_score[1])
# Out:
# Train on 156672 samples, validate on 17408 samples
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/80
#  - 293s - loss: 3.4307 - top_3_categorical_accuracy: 0.4510 - val_loss: 2.4382 - val_top_3_categorical_accuracy: 0.6497
# Epoch 2/80
#  - 293s - loss: 2.5553 - top_3_categorical_accuracy: 0.6235 - val_loss: 2.2277 - val_top_3_categorical_accuracy: 0.6912
# Epoch 3/80
#  - 302s - loss: 2.2929 - top_3_categorical_accuracy: 0.6733 - val_loss: 2.1019 - val_top_3_categorical_accuracy: 0.7152
# Epoch 4/80
#  - 300s - loss: 2.1183 - top_3_categorical_accuracy: 0.7032 - val_loss: 2.0049 - val_top_3_categorical_accuracy: 0.7312
# Epoch 5/80
#  - 299s - loss: 1.9936 - top_3_categorical_accuracy: 0.7249 - val_loss: 1.9934 - val_top_3_categorical_accuracy: 0.7306
# Epoch 6/80
#  - 301s - loss: 1.8880 - top_3_categorical_accuracy: 0.7441 - val_loss: 1.9694 - val_top_3_categorical_accuracy: 0.7375
# Epoch 7/80
#  - 299s - loss: 1.8022 - top_3_categorical_accuracy: 0.7585 - val_loss: 1.9631 - val_top_3_categorical_accuracy: 0.7398
# Epoch 8/80
#  - 295s - loss: 1.7211 - top_3_categorical_accuracy: 0.7707 - val_loss: 1.9560 - val_top_3_categorical_accuracy: 0.7430
# Epoch 9/80
#  - 302s - loss: 1.6551 - top_3_categorical_accuracy: 0.7822 - val_loss: 1.9792 - val_top_3_categorical_accuracy: 0.7366
# Epoch 10/80
#  - 301s - loss: 1.5998 - top_3_categorical_accuracy: 0.7912 - val_loss: 1.9551 - val_top_3_categorical_accuracy: 0.7414
# Epoch 11/80
#  - 297s - loss: 1.5436 - top_3_categorical_accuracy: 0.8004 - val_loss: 1.9528 - val_top_3_categorical_accuracy: 0.7410
# Epoch 12/80
#  - 297s - loss: 1.4985 - top_3_categorical_accuracy: 0.8075 - val_loss: 1.9982 - val_top_3_categorical_accuracy: 0.7399
# Epoch 13/80
#  - 296s - loss: 1.4588 - top_3_categorical_accuracy: 0.8149 - val_loss: 2.0036 - val_top_3_categorical_accuracy: 0.7379
# Epoch 14/80
#  - 299s - loss: 1.4220 - top_3_categorical_accuracy: 0.8197 - val_loss: 2.0025 - val_top_3_categorical_accuracy: 0.7353
# Epoch 15/80
#  - 299s - loss: 1.3915 - top_3_categorical_accuracy: 0.8256 - val_loss: 2.0336 - val_top_3_categorical_accuracy: 0.7358
# Epoch 16/80
#  - 299s - loss: 1.3533 - top_3_categorical_accuracy: 0.8320 - val_loss: 2.0390 - val_top_3_categorical_accuracy: 0.7379
# Epoch 17/80
#  - 298s - loss: 1.3294 - top_3_categorical_accuracy: 0.8361 - val_loss: 2.0446 - val_top_3_categorical_accuracy: 0.7342
# Epoch 18/80
#  - 299s - loss: 1.3080 - top_3_categorical_accuracy: 0.8387 - val_loss: 2.0948 - val_top_3_categorical_accuracy: 0.7332
# Epoch 19/80
#  - 297s - loss: 1.2796 - top_3_categorical_accuracy: 0.8435 - val_loss: 2.0604 - val_top_3_categorical_accuracy: 0.7363
# Epoch 20/80
#  - 299s - loss: 1.2534 - top_3_categorical_accuracy: 0.8484 - val_loss: 2.1084 - val_top_3_categorical_accuracy: 0.7329
# Epoch 21/80
#  - 295s - loss: 1.2465 - top_3_categorical_accuracy: 0.8501 - val_loss: 2.1073 - val_top_3_categorical_accuracy: 0.7329
# Epoch 22/80
#  - 294s - loss: 1.2204 - top_3_categorical_accuracy: 0.8544 - val_loss: 2.0701 - val_top_3_categorical_accuracy: 0.7322
# Epoch 23/80
#  - 295s - loss: 1.1994 - top_3_categorical_accuracy: 0.8580 - val_loss: 2.1397 - val_top_3_categorical_accuracy: 0.7335
# Epoch 24/80
#  - 297s - loss: 1.1829 - top_3_categorical_accuracy: 0.8604 - val_loss: 2.1269 - val_top_3_categorical_accuracy: 0.7295
# Epoch 25/80
#  - 298s - loss: 1.1726 - top_3_categorical_accuracy: 0.8618 - val_loss: 2.1919 - val_top_3_categorical_accuracy: 0.7281
# Epoch 26/80
#  - 297s - loss: 1.1615 - top_3_categorical_accuracy: 0.8634 - val_loss: 2.1624 - val_top_3_categorical_accuracy: 0.7299
# Epoch 27/80
#  - 298s - loss: 1.1454 - top_3_categorical_accuracy: 0.8670 - val_loss: 2.1628 - val_top_3_categorical_accuracy: 0.7268
# Epoch 28/80
#  - 297s - loss: 1.1443 - top_3_categorical_accuracy: 0.8678 - val_loss: 2.1366 - val_top_3_categorical_accuracy: 0.7279
# Epoch 29/80
#  - 299s - loss: 1.1224 - top_3_categorical_accuracy: 0.8710 - val_loss: 2.1567 - val_top_3_categorical_accuracy: 0.7226
# Epoch 30/80
#  - 297s - loss: 1.1134 - top_3_categorical_accuracy: 0.8714 - val_loss: 2.2732 - val_top_3_categorical_accuracy: 0.7324
# Epoch 31/80
#  - 301s - loss: 1.1010 - top_3_categorical_accuracy: 0.8753 - val_loss: 2.2294 - val_top_3_categorical_accuracy: 0.7248
# Epoch 32/80
#  - 300s - loss: 1.0955 - top_3_categorical_accuracy: 0.8756 - val_loss: 2.2289 - val_top_3_categorical_accuracy: 0.7295
# Epoch 33/80
#  - 299s - loss: 1.0901 - top_3_categorical_accuracy: 0.8768 - val_loss: 2.1763 - val_top_3_categorical_accuracy: 0.7270
# Epoch 34/80
#  - 293s - loss: 1.0770 - top_3_categorical_accuracy: 0.8781 - val_loss: 2.2259 - val_top_3_categorical_accuracy: 0.7277
# Epoch 35/80
#  - 296s - loss: 1.0724 - top_3_categorical_accuracy: 0.8792 - val_loss: 2.2377 - val_top_3_categorical_accuracy: 0.7225
# Epoch 36/80
#  - 298s - loss: 1.0635 - top_3_categorical_accuracy: 0.8806 - val_loss: 2.2693 - val_top_3_categorical_accuracy: 0.7222
# Epoch 37/80
#  - 299s - loss: 1.0652 - top_3_categorical_accuracy: 0.8811 - val_loss: 2.4032 - val_top_3_categorical_accuracy: 0.7278
# Epoch 38/80
#  - 297s - loss: 1.0511 - top_3_categorical_accuracy: 0.8839 - val_loss: 2.2330 - val_top_3_categorical_accuracy: 0.7236
# Epoch 39/80
#  - 296s - loss: 1.0487 - top_3_categorical_accuracy: 0.8846 - val_loss: 2.2792 - val_top_3_categorical_accuracy: 0.7237
# Epoch 40/80
#  - 297s - loss: 1.0429 - top_3_categorical_accuracy: 0.8840 - val_loss: 2.3270 - val_top_3_categorical_accuracy: 0.7269
# Epoch 41/80
#  - 297s - loss: 1.0396 - top_3_categorical_accuracy: 0.8849 - val_loss: 2.3294 - val_top_3_categorical_accuracy: 0.7250
# Epoch 42/80
#  - 298s - loss: 1.0299 - top_3_categorical_accuracy: 0.8869 - val_loss: 2.3282 - val_top_3_categorical_accuracy: 0.7204
# Epoch 43/80
#  - 299s - loss: 1.0242 - top_3_categorical_accuracy: 0.8885 - val_loss: 2.3344 - val_top_3_categorical_accuracy: 0.7235
# Epoch 44/80
#  - 298s - loss: 1.0221 - top_3_categorical_accuracy: 0.8884 - val_loss: 2.3707 - val_top_3_categorical_accuracy: 0.7246
# Epoch 45/80
#  - 298s - loss: 1.0171 - top_3_categorical_accuracy: 0.8888 - val_loss: 2.3520 - val_top_3_categorical_accuracy: 0.7245
# Epoch 46/80
#  - 300s - loss: 1.0133 - top_3_categorical_accuracy: 0.8898 - val_loss: 2.3386 - val_top_3_categorical_accuracy: 0.7256
# Epoch 47/80
#  - 301s - loss: 1.0101 - top_3_categorical_accuracy: 0.8905 - val_loss: 2.3743 - val_top_3_categorical_accuracy: 0.7239
# Epoch 48/80
#  - 298s - loss: 1.0061 - top_3_categorical_accuracy: 0.8916 - val_loss: 2.3290 - val_top_3_categorical_accuracy: 0.7186
# Epoch 49/80
#  - 298s - loss: 1.0056 - top_3_categorical_accuracy: 0.8919 - val_loss: 2.4392 - val_top_3_categorical_accuracy: 0.7258
# Epoch 50/80
#  - 298s - loss: 0.9996 - top_3_categorical_accuracy: 0.8935 - val_loss: 2.4252 - val_top_3_categorical_accuracy: 0.7239
# Epoch 51/80
#  - 302s - loss: 0.9906 - top_3_categorical_accuracy: 0.8938 - val_loss: 2.3724 - val_top_3_categorical_accuracy: 0.7225
# Epoch 52/80
#  - 301s - loss: 0.9936 - top_3_categorical_accuracy: 0.8941 - val_loss: 2.5262 - val_top_3_categorical_accuracy: 0.7255
# Epoch 53/80
#  - 301s - loss: 0.9976 - top_3_categorical_accuracy: 0.8925 - val_loss: 2.2550 - val_top_3_categorical_accuracy: 0.7107
# Epoch 54/80
#  - 300s - loss: 0.9919 - top_3_categorical_accuracy: 0.8937 - val_loss: 2.3684 - val_top_3_categorical_accuracy: 0.7205
# Epoch 55/80
#  - 301s - loss: 0.9806 - top_3_categorical_accuracy: 0.8964 - val_loss: 2.4001 - val_top_3_categorical_accuracy: 0.7174
# Epoch 56/80
#  - 298s - loss: 0.9850 - top_3_categorical_accuracy: 0.8959 - val_loss: 2.4866 - val_top_3_categorical_accuracy: 0.7233
# Epoch 57/80
#  - 299s - loss: 0.9760 - top_3_categorical_accuracy: 0.8976 - val_loss: 2.3964 - val_top_3_categorical_accuracy: 0.7152
# Epoch 58/80
#  - 301s - loss: 0.9757 - top_3_categorical_accuracy: 0.8968 - val_loss: 2.4971 - val_top_3_categorical_accuracy: 0.7232
# Epoch 59/80
#  - 300s - loss: 0.9823 - top_3_categorical_accuracy: 0.8955 - val_loss: 2.3760 - val_top_3_categorical_accuracy: 0.7166
# Epoch 60/80
#  - 300s - loss: 0.9734 - top_3_categorical_accuracy: 0.8977 - val_loss: 2.5216 - val_top_3_categorical_accuracy: 0.7249
# Epoch 61/80
#  - 298s - loss: 0.9725 - top_3_categorical_accuracy: 0.8989 - val_loss: 2.3479 - val_top_3_categorical_accuracy: 0.7152
# Epoch 62/80
#  - 299s - loss: 0.9688 - top_3_categorical_accuracy: 0.8986 - val_loss: 2.4625 - val_top_3_categorical_accuracy: 0.7190
# Epoch 63/80
#  - 298s - loss: 0.9684 - top_3_categorical_accuracy: 0.8981 - val_loss: 2.4544 - val_top_3_categorical_accuracy: 0.7173
# Epoch 64/80
#  - 299s - loss: 0.9693 - top_3_categorical_accuracy: 0.8984 - val_loss: 2.4522 - val_top_3_categorical_accuracy: 0.7154
# Epoch 65/80
#  - 300s - loss: 0.9676 - top_3_categorical_accuracy: 0.8984 - val_loss: 2.5530 - val_top_3_categorical_accuracy: 0.7227
# Epoch 66/80
#  - 300s - loss: 0.9662 - top_3_categorical_accuracy: 0.9001 - val_loss: 2.7220 - val_top_3_categorical_accuracy: 0.7271
# Epoch 67/80
#  - 294s - loss: 0.9718 - top_3_categorical_accuracy: 0.8986 - val_loss: 2.5684 - val_top_3_categorical_accuracy: 0.7219
# Epoch 68/80
#  - 299s - loss: 0.9683 - top_3_categorical_accuracy: 0.9002 - val_loss: 2.5083 - val_top_3_categorical_accuracy: 0.7175
# Epoch 69/80
#  - 298s - loss: 0.9615 - top_3_categorical_accuracy: 0.9006 - val_loss: 2.4511 - val_top_3_categorical_accuracy: 0.7088
# Epoch 70/80
#  - 299s - loss: 0.9581 - top_3_categorical_accuracy: 0.9012 - val_loss: 2.4435 - val_top_3_categorical_accuracy: 0.7181
# Epoch 71/80
#  - 302s - loss: 0.9642 - top_3_categorical_accuracy: 0.9007 - val_loss: 2.5233 - val_top_3_categorical_accuracy: 0.7175
# Epoch 72/80
#  - 296s - loss: 0.9603 - top_3_categorical_accuracy: 0.9010 - val_loss: 2.6523 - val_top_3_categorical_accuracy: 0.7202
# Epoch 73/80
#  - 299s - loss: 0.9595 - top_3_categorical_accuracy: 0.9016 - val_loss: 2.7214 - val_top_3_categorical_accuracy: 0.7250
# Epoch 74/80
#  - 300s - loss: 0.9552 - top_3_categorical_accuracy: 0.9015 - val_loss: 2.4564 - val_top_3_categorical_accuracy: 0.7123
# Epoch 75/80
#  - 299s - loss: 0.9581 - top_3_categorical_accuracy: 0.9012 - val_loss: 2.7565 - val_top_3_categorical_accuracy: 0.7191
# Epoch 76/80
#  - 300s - loss: 0.9646 - top_3_categorical_accuracy: 0.9003 - val_loss: 2.6604 - val_top_3_categorical_accuracy: 0.7223
# Epoch 77/80
#  - 298s - loss: 0.9568 - top_3_categorical_accuracy: 0.9015 - val_loss: 2.5415 - val_top_3_categorical_accuracy: 0.7117
# Epoch 78/80
#  - 299s - loss: 0.9581 - top_3_categorical_accuracy: 0.9022 - val_loss: 2.7197 - val_top_3_categorical_accuracy: 0.7217
# Epoch 79/80
#  - 299s - loss: 0.9555 - top_3_categorical_accuracy: 0.9025 - val_loss: 2.4546 - val_top_3_categorical_accuracy: 0.7127
# Epoch 80/80
#  - 300s - loss: 0.9604 - top_3_categorical_accuracy: 0.9018 - val_loss: 2.4717 - val_top_3_categorical_accuracy: 0.7082
# 17408/17408 [==============================] - 7s 401us/sample - loss: 2.4717 - top_3_categorical_accuracy: 0.7082
# keras
#   top 3 categorical accuracy score: 0.7082

# %%
# keras model save
model_keras.save('model_keras.h5')

# %%
# memory clean-up
del x_train, x_validate, y_train, y_validate

# %% [markdown]
# > **Supply or submit the results**
#
# Our submission to the competition site Kaggle is ready. Any suggestions to improve our score are welcome.

# %%
# acquiring testing data
df_test = pd.read_csv('../input/test_simplified.csv')

# combine testing dataframe
df_test['datatype'] = 'testing'
df_test['word'], df_test['recognized'] = '', True

# feature extraction: step 1
df_test = feature_extraction(df_test)

# feature extraction: step 2
df_test = feature_extraction2(df_test)

# %%
# prepare testing data and compute the observed value
x_test = np.zeros((df_test.shape[0], img_size, img_size, 1))
for i, df_row in df_test.iterrows(): x_test[i, :, :, 0] = df_row['pixel']
y_test = np.argsort(-model_keras.predict(x_test, verbose=1))[:, 0:3]
df_word = pd.DataFrame({'top 1': y_test[:, 0], 'top 2': y_test[:, 1], 'top 3': y_test[:, 2]})
df_word = df_word.replace(classreverse_dict)
df_word['submission'] = df_word['top 1'] + ' ' + df_word['top 2'] + ' ' + df_word['top 3']
# Out:
# 112199/112199 [==============================] - 43s 382us/sample

# %%
# summit the results
out = pd.DataFrame({'key_id': df_test['key_id'], 'word': df_word['submission']})
out.to_csv('submission.csv', index=False)
